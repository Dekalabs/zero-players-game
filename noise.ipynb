# %%
import numpy as np

WIDTH = 1024
HEIGHT = 600
BLOCK = 10


tile = np.empty((WIDTH // BLOCK, HEIGHT // BLOCK))

# %%
import opensimplex


opensimplex.seed(1234)

# %%
scale = 20
for x in range(WIDTH // BLOCK):
    for y in range(HEIGHT // BLOCK):
        tile[x, y] = opensimplex.noise2(x/scale, y/scale)

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt



fig, ax = plt.subplots()
im = ax.imshow(tile.T)
plt.show()

# %%
tile2 = np.empty((WIDTH // BLOCK, HEIGHT // BLOCK))

# %%
import noise

scale = 10
for x in range(WIDTH // BLOCK):
    for y in range(HEIGHT // BLOCK):
        tile2[x, y] = noise.pnoise2(x/scale, y/scale)

# %%
fig, ax = plt.subplots()
im = ax.imshow(tile2.T)
plt.show()
